# %%
def add(a, b) :
  return a + b

print(add(1,2))
# Out:
# 3

# %%
def cal(a, b) :
  return a - b

print(cal(1,2))
# Out:
# -1

# %%
def cal(a, b) :
  return a * b

print(cal(1,2))
# Out:
# 2

# %%
def cal(a, b) :
  return a / b

print(cal(1,2))
# Out:
# 0.5
